# %%
import pandas as pd

# %%
df = pd.read_excel("Cal Nonprofits - Dental and Vision.xlsx")
df = df.iloc[3:]
df.columns = ['EEID','Name','Title','Site','Setal','Detal','Vision','Vision2','Un']
df.head(10)
# Out:
#                     Name                     Title         Site  Setal  Detal  \
# 3      Altmann, Catalina         Assistant Teacher     Broadway  46.95  46.95
# 4   Bandelaria, Evelyn A              Site Manager     Broadway  46.95  46.95
# 5          Chiu, Yu Ming         Assistant Teacher  North Beach  46.95  46.95
# 6          Crayne, Masha  Resource Development Mgr       Admin   46.95  46.95
# 7           Deng, Li Mei              Lead Teacher          TKL   89.1   89.1
# 8          Dong, Ruifang            HR Coordinator       Admin   46.95  46.95
# 9            Dore, Holly              Lead Teacher        Geary  46.95  46.95
# 10          Heung, Sonia           Family Advocate  North Beach  46.95  46.95
# 11         Hoi, Shermond              Lead Teacher       Sunset  46.95  46.95
# 12        Huang, Bi Juan              Site Manager     Broadway  46.95  46.95
#
#    Vision Vision2  Un
# 3     8.8     8.8 NaN
# 4     8.8     8.8 NaN
# 5     8.8     8.8 NaN
# ...

# %%
k_df = df[df['Name'] == "Rodriguez Madera, Krystal"]
k_df
# Out:
# Empty DataFrame
# Columns: [Name, Title, Site, Setal, Detal, Vision, Vision2, Un]
# Index: []
